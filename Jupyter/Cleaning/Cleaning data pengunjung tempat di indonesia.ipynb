# %%
import pandas
import numpy

# %%
data = pandas.read_csv("../../Dataset/Covid/Pengunjung tempat di Indonesia.csv")

# %%
data
# Out:
#              Entity Code         Day  retail_and_recreation  \
# 0       Afghanistan  AFG  2020-02-17                  0.000
# 1       Afghanistan  AFG  2020-02-18                  0.750
# 2       Afghanistan  AFG  2020-02-19                  0.400
# 3       Afghanistan  AFG  2020-02-20                  0.000
# 4       Afghanistan  AFG  2020-02-21                  0.000
# ...             ...  ...         ...                    ...
# 127867     Zimbabwe  ZWE  2022-10-11                135.000
# 127868     Zimbabwe  ZWE  2022-10-12                133.857
# 127869     Zimbabwe  ZWE  2022-10-13                133.000
# 127870     Zimbabwe  ZWE  2022-10-14                132.714
# 127871     Zimbabwe  ZWE  2022-10-15                132.429
#
#         grocery_and_pharmacy  residential  transit_stations    parks  \
# 0                      4.000        1.333             5.667    1.000
# 1                      4.250        0.750             6.500    1.500
# ...

# %%
data_indonesia = data[data["Entity"]=="Indonesia"]

# %%
data_indonesia = data_indonesia.reset_index()

# %%
data_indonesia = data_indonesia.drop("index", axis=1)

# %%
data_indonesia
# Out:
#         Entity Code         Day  retail_and_recreation  grocery_and_pharmacy  \
# 0    Indonesia  IDN  2020-02-17                 -2.667                -3.000
# 1    Indonesia  IDN  2020-02-18                 -2.750                -2.750
# 2    Indonesia  IDN  2020-02-19                 -2.800                -3.000
# 3    Indonesia  IDN  2020-02-20                 -2.667                -2.667
# 4    Indonesia  IDN  2020-02-21                 -2.571                -2.714
# ..         ...  ...         ...                    ...                   ...
# 967  Indonesia  IDN  2022-10-11                 11.571                30.571
# 968  Indonesia  IDN  2022-10-12                 11.143                29.714
# 969  Indonesia  IDN  2022-10-13                 11.143                29.429
# 970  Indonesia  IDN  2022-10-14                 11.286                29.286
# 971  Indonesia  IDN  2022-10-15                 11.000                29.143
#
# ...

# %%
data_indonesia.to_csv("Data pengunjung di Indonesia.csv")
