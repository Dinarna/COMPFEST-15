# %%
import pandas
import numpy

# %%
data_17_19 = pandas.read_excel("../../Dataset/Banjir/Jumlah Penduduk Provinsi DKI Jakarta Menurut Kelompok Umur dan Jenis Kelamin_17_19.xlsx")
data_20_22 = pandas.read_excel("../../Dataset/Banjir/Jumlah Penduduk Provinsi DKI Jakarta Menurut Kelompok Umur dan Jenis Kelamin_20_22.xlsx")

# %%
data_17_19
# Out:
#                                         Kelompok Umur  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 0-4
# 3                                                 5-9
# 4                                               10-14
# 5                                               15-19
# 6                                               20-24
# 7                                               25-29
# 8                                               30-34
# 9                                               35-39
# 10                                              40-44
# 11                                              45-49
# 12                                              50-54
# 13                                              55-59
# 14                                              60-64
# 15                                                65+
# ...

# %%
data_20_22
# Out:
#                                         Kelompok Umur  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 0-4
# 3                                                 5-9
# 4                                               10-14
# 5                                               15-19
# 6                                               20-24
# 7                                               25-29
# 8                                               30-34
# 9                                               35-39
# 10                                              40-44
# 11                                              45-49
# 12                                              50-54
# 13                                              55-59
# 14                                              60-64
# 15                                                65+
# ...

# %%
kolom = ["2017","2018","2019","2020","2021","2022"]
data  = pandas.DataFrame(columns=kolom)

# %%
data = data.append({
    "2017":,
    "2018":,
    "2019":,
    "2020":,
    "2021":,
    "2022":,
},ignore_index=True)
